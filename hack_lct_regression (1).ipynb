# %%
# !pip install geodist >> none
from geodist import GeoDist

# !pip install catboost >> none
from catboost import CatBoostRegressor, Pool

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re

from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
import pickle

from google.colab import drive
drive.mount('/content/gdrive')

import warnings
warnings.filterwarnings('ignore')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # Анализ и обработка данных

# %%
df = pd.read_csv('/content/gdrive/MyDrive/data csv/formatted.csv')
df.head()
# Out:
#            id                  coords rooms_count    year  house_floors  \
# 0  2624808613  (55.680879, 37.738863)           1  2021.0          13.0
# 1  2532916318  (55.796471, 37.609919)      студия  1971.0           8.0
# 2  2587872760   (55.740624, 37.66645)           2  1984.0          12.0
# 3  2543206638  (55.829437, 37.414219)      студия     NaN           4.0
# 4  2658418970  (55.805169, 37.540695)           3     NaN           8.0
#
#     material  floor  flat_area  kitchen_area balcony       metro  \
# 0  панельный   13.0       36.7          10.3  лоджия  21–30 мин.
# 1    блочный    5.0       32.0           NaN     NaN   6–10 мин.
# 2  панельный    4.0       52.0          10.0  лоджия   6–10 мин.
# 3    блочный    1.0       21.1           NaN     NaN  16–20 мин.
# 4  кирпичный    1.0       68.7          11.0     NaN   6–10 мин.
#
#          condition     price  \
# 0    косметический   9500000
# 1     дизайнерский  10490000
# 2             евро  17500000
# 3             евро   3258000
# 4  требует ремонта  16500000
#
#                                                  url
# 0  /moskva/kvartiry/1-k._kvartira_367m_1313et._26...
# 1  /moskva/kvartiry/apartamenty-studiya_32m_58et....
# 2  /moskva/kvartiry/2-k._kvartira_52m_412et._2587...
# 3  /moskva/kvartiry/apartamenty-studiya_211m_14et...
# 4  /moskva/kvartiry/3-k._kvartira_687m_18et._2658...

# %%
df = df.drop(['id', 'url'], axis=1)


def dist(x):
        s = [float(s) for s in re.findall(r'-?\d+\.?\d*', x)]
        s[0], s[1] = s[1], s[0]
        s = tuple(s)
        res = float(format(GeoDist([s]).distance(37.617734, 55.751999)/1000, '.3f'))
        return res

df['coords'] = [dist(x) for x in df['coords']]


df = df.dropna(thresh=4)
df = df.reset_index(drop=True)

df.year = df.year.replace(0, np.nan)
df.year[932] = 2021.0
df.year[990] = 1976.0
df.year[1706] = 1956.0


monolit = df.loc[(df.material == 'монолитный') & (df.year.isna() == False)]
panel = df.loc[(df.material == 'панельный') & (df.year.isna() == False)]
brick = df.loc[(df.material == 'кирпичный') & (df.year.isna() == False)]
monolit_brick = df.loc[(df.material == 'монолитно-кирпичный') & (df.year.isna() == False)]
block = df.loc[(df.material == 'блочный') & (df.year.isna() == False)]

for i in range(df.shape[0]):
    if df.year[i] != df.year[i]:
        if df.material[i] == 'монолитный':
            df.year[i] = monolit.year.mean()
        elif df.material[i] == 'панельный':
            df.year[i] = panel.year.mean()
        elif df.material[i] == 'кирпичный':
            df.year[i] = brick.year.mean()
        elif df.material[i] == 'блочный':
            df.year[i] = block.year.mean()
        else:
            df.year[i] = monolit_brick.year.mean()

df.year = df.year.astype(int)


kitchen_coef = df.flat_area.mean() / df.kitchen_area.mean()

for i in range(df.shape[0]):
    if df.kitchen_area[i] != df.kitchen_area[i]:
        df.kitchen_area[i] = format(df.flat_area[i] / kitchen_coef, '.1f')
        if df.kitchen_area[i] < 5: df.kitchen_area[i] = 5


df.balcony = df.balcony.fillna('нет')
df.metro = df.metro.fillna('6–10 мин.')


for i in range(df.shape[0]):
    if df.condition[i] != df.condition[i]:
        if df.coords[i] < 10:
            if 2000 < df.year[i] < 2020 and df.price[i] > df.price.mean():
                df.condition[i] = 'евро'
            else:
                df.condition[i] = 'косметический'
        else:
            df.condition[i] = 'требует ремонта'

df.sample(7)
# Out:
#        coords rooms_count  year  house_floors             material  floor  \
# 2829    8.754           2  1971          14.0              блочный    5.0
# 14803   3.045           5  1961          19.0            кирпичный   13.0
# 12264  13.069           9  2006           6.0           монолитный    4.0
# 8142   10.560      студия  1982          22.0            панельный    1.0
# 14191   4.276           4  2011          65.0           монолитный   11.0
# 3750   12.537      студия  1957           5.0  монолитно-кирпичный    1.0
# 881    21.167      студия  1995          17.0            панельный    2.0
#
#        flat_area  kitchen_area balcony       metro        condition      price
# 2829        38.0           6.0  лоджия  11–15 мин.             евро   12500000
# 14803      205.0          20.0  балкон   6–10 мин.  требует ремонта  105000000
# 12264      528.5          20.0  балкон  от 31 мин.    косметический  495000000
# 8142        14.8           5.0     нет  11–15 мин.    косметический    2940000
# 14191      129.8          19.5     нет   6–10 мин.             евро  128541600
# 3750        24.0           5.0     нет  16–20 мин.     дизайнерский    7190000
# 881         19.8           5.0  балкон   6–10 мин.  требует ремонта    4800000

# %%
df.corr().style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style type="text/css">
# #T_e09f7_row0_col0, #T_e09f7_row1_col1, #T_e09f7_row2_col2, #T_e09f7_row3_col3, #T_e09f7_row4_col4, #T_e09f7_row5_col5, #T_e09f7_row6_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_e09f7_row0_col1, #T_e09f7_row0_col2, #T_e09f7_row0_col3, #T_e09f7_row0_col4, #T_e09f7_row0_col5, #T_e09f7_row0_col6, #T_e09f7_row6_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_e09f7_row1_col0, #T_e09f7_row2_col1 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_e09f7_row1_col2 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_e09f7_row1_col3 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_e09f7_row1_col4 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_e09f7_row1_col5 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_e09f7_row1_col6 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_e09f7_row2_col0 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_e09f7_row2_col3 {
#   background-color: #e8765c;
#   color: #f1f1f1;
# }
# #T_e09f7_row2_col4 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_e09f7_row2_col5 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_e09f7_row2_col6 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_e09f7_row3_col0, #T_e09f7_row5_col1, #T_e09f7_row6_col3 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_e09f7_row3_col1 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_e09f7_row3_col2 {
#   background-color: #eb7d62;
#   color: #f1f1f1;
# }
# #T_e09f7_row3_col4 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_e09f7_row3_col5 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_e09f7_row3_col6 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_e09f7_row4_col0 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_e09f7_row4_col1 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_e09f7_row4_col2 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_e09f7_row4_col3 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_e09f7_row4_col5 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_e09f7_row4_col6, #T_e09f7_row6_col4 {
#   background-color: #e9785d;
#   color: #f1f1f1;
# }
# #T_e09f7_row5_col0 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_e09f7_row5_col2 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_e09f7_row5_col3 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_e09f7_row5_col4 {
#   background-color: #f39577;
#   color: #000000;
# }
# #T_e09f7_row5_col6 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_e09f7_row6_col1 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_e09f7_row6_col2 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_e09f7_row6_col5 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# </style>
# <table id="T_e09f7_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >coords</th>
#       <th class="col_heading level0 col1" >year</th>
#       <th class="col_heading level0 col2" >house_floors</th>
#       <th class="col_heading level0 col3" >floor</th>
#       <th class="col_heading level0 col4" >flat_area</th>
#       <th class="col_heading level0 col5" >kitchen_area</th>
#       <th class="col_heading level0 col6" >price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e09f7_level0_row0" class="row_heading level0 row0" >coords</th>
#       <td id="T_e09f7_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_e09f7_row0_col1" class="data row0 col1" >0.06</td>
#       <td id="T_e09f7_row0_col2" class="data row0 col2" >-0.01</td>
#       <td id="T_e09f7_row0_col3" class="data row0 col3" >-0.12</td>
#       <td id="T_e09f7_row0_col4" class="data row0 col4" >-0.43</td>
#       <td id="T_e09f7_row0_col5" class="data row0 col5" >-0.34</td>
#       <td id="T_e09f7_row0_col6" class="data row0 col6" >-0.45</td>
#     </tr>
#     <tr>
#       <th id="T_e09f7_level0_row1" class="row_heading level0 row1" >year</th>
#       <td id="T_e09f7_row1_col0" class="data row1 col0" >0.06</td>
#       <td id="T_e09f7_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_e09f7_row1_col2" class="data row1 col2" >0.39</td>
#       <td id="T_e09f7_row1_col3" class="data row1 col3" >0.33</td>
#       <td id="T_e09f7_row1_col4" class="data row1 col4" >0.23</td>
#       <td id="T_e09f7_row1_col5" class="data row1 col5" >0.27</td>
#       <td id="T_e09f7_row1_col6" class="data row1 col6" >0.19</td>
#     </tr>
#     <tr>
#       <th id="T_e09f7_level0_row2" class="row_heading level0 row2" >house_floors</th>
#       <td id="T_e09f7_row2_col0" class="data row2 col0" >-0.01</td>
#       <td id="T_e09f7_row2_col1" class="data row2 col1" >0.39</td>
#       <td id="T_e09f7_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_e09f7_row2_col3" class="data row2 col3" >0.81</td>
#       <td id="T_e09f7_row2_col4" class="data row2 col4" >0.16</td>
#       <td id="T_e09f7_row2_col5" class="data row2 col5" >0.18</td>
#       <td id="T_e09f7_row2_col6" class="data row2 col6" >0.02</td>
#     </tr>
#     <tr>
#       <th id="T_e09f7_level0_row3" class="row_heading level0 row3" >floor</th>
#       <td id="T_e09f7_row3_col0" class="data row3 col0" >-0.12</td>
#       <td id="T_e09f7_row3_col1" class="data row3 col1" >0.33</td>
#       <td id="T_e09f7_row3_col2" class="data row3 col2" >0.81</td>
#       <td id="T_e09f7_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_e09f7_row3_col4" class="data row3 col4" >0.28</td>
#       <td id="T_e09f7_row3_col5" class="data row3 col5" >0.26</td>
#       <td id="T_e09f7_row3_col6" class="data row3 col6" >0.13</td>
#     </tr>
#     <tr>
#       <th id="T_e09f7_level0_row4" class="row_heading level0 row4" >flat_area</th>
#       <td id="T_e09f7_row4_col0" class="data row4 col0" >-0.43</td>
#       <td id="T_e09f7_row4_col1" class="data row4 col1" >0.23</td>
#       <td id="T_e09f7_row4_col2" class="data row4 col2" >0.16</td>
#       <td id="T_e09f7_row4_col3" class="data row4 col3" >0.28</td>
#       <td id="T_e09f7_row4_col4" class="data row4 col4" >1.00</td>
#       <td id="T_e09f7_row4_col5" class="data row4 col5" >0.65</td>
#       <td id="T_e09f7_row4_col6" class="data row4 col6" >0.75</td>
#     </tr>
#     <tr>
#       <th id="T_e09f7_level0_row5" class="row_heading level0 row5" >kitchen_area</th>
#       <td id="T_e09f7_row5_col0" class="data row5 col0" >-0.34</td>
#       <td id="T_e09f7_row5_col1" class="data row5 col1" >0.27</td>
#       <td id="T_e09f7_row5_col2" class="data row5 col2" >0.18</td>
#       <td id="T_e09f7_row5_col3" class="data row5 col3" >0.26</td>
#       <td id="T_e09f7_row5_col4" class="data row5 col4" >0.65</td>
#       <td id="T_e09f7_row5_col5" class="data row5 col5" >1.00</td>
#       <td id="T_e09f7_row5_col6" class="data row5 col6" >0.51</td>
#     </tr>
#     <tr>
#       <th id="T_e09f7_level0_row6" class="row_heading level0 row6" >price</th>
#       <td id="T_e09f7_row6_col0" class="data row6 col0" >-0.45</td>
#       <td id="T_e09f7_row6_col1" class="data row6 col1" >0.19</td>
#       <td id="T_e09f7_row6_col2" class="data row6 col2" >0.02</td>
#       <td id="T_e09f7_row6_col3" class="data row6 col3" >0.13</td>
#       <td id="T_e09f7_row6_col4" class="data row6 col4" >0.75</td>
#       <td id="T_e09f7_row6_col5" class="data row6 col5" >0.51</td>
#       <td id="T_e09f7_row6_col6" class="data row6 col6" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
num_cols = ['coords',
            'year',
            'house_floors',
            'floor',
            'flat_area',
            'kitchen_area']

cat_cols = ['rooms_count',
            'material',
            'balcony',
            'metro',
            'condition']
            
target_col = df.price

# %%
df = df.iloc[:, :-1]

# %% [markdown]
# # Обучение

# %%
X_train, X_test, y_train, y_test = train_test_split(df, target_col)

# %%
boosting_model = CatBoostRegressor(cat_features = cat_cols)

# %%
params = {
    'depth' : [6, 7, 8, 9, 10],
    'learning_rate' : [0.01, 0.02, 0.03, 0.04],
    'iterations' : [100, 200, 300]
}

grid_model = GridSearchCV(estimator=boosting_model,
                        param_grid = params,
                        n_jobs=-1)

grid_model.fit(X_train, y_train)

# %%
pred = grid_model.predict(X_test)
r2 = r2_score(y_test, pred)
print('R2: {:.2f}'.format(r2))
# Out:
# R2: 0.85

# %%
filename = 'lct_model.sav'
pickle.dump(open(filename, 'wb'))
